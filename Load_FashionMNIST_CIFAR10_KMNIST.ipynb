# %% [markdown]
# <a href="https://colab.research.google.com/github/Teacher-Heiko/fastbook/blob/master/Load_FashionMNIST_CIFAR10_KMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Some boilerplate code to download datasets and display some random images.

# %%
# !pip install torch torchvision -Uq

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Set up data transform to convert images to tensors
transform = transforms.ToTensor()

# Load the Fashion MNIST dataset
fashionmnist_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
# Out:
# ...
# 100%|██████████| 26421880/26421880 [00:01<00:00, 22114985.09it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 29515/29515 [00:00<00:00, 338271.58it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 4422102/4422102 [00:00<00:00, 6289256.52it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# ...
# 100%|██████████| 5148/5148 [00:00<00:00, 6162179.51it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
def display_images(images, labels):
    fig, axes = plt.subplots(2, 5, figsize=(5, 5))  # 2 rows, 5 columns, 10 inches by 5 inches
    axes = axes.ravel()  # Flatten the array of axes to easily iterate through it
    for idx, image in enumerate(images):
        axes[idx].imshow(transforms.ToPILImage()(image), cmap='gray')
        axes[idx].set_title(labels[idx])
        axes[idx].axis('off')
    plt.tight_layout()  # Adjusts the spacing between subplots
    plt.show()

# Get random indices
indices = torch.randperm(len(fashionmnist_dataset))[:10]

# Get random images and labels
random_images = [fashionmnist_dataset[i][0] for i in indices]
random_labels = [str(fashionmnist_dataset[i][1]) for i in indices]

# Display the images
display_images(random_images, random_labels)

# %%
import torch
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np


# Set up data transform to convert images to tensors
transform = transforms.ToTensor()

# Load the CIFAR-10 dataset
cifar10_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# Out:
# ...
# 100%|██████████| 170498071/170498071 [00:01<00:00, 102597876.37it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
import torch

print(torch.__version__)
# Out:
# 2.0.1+cu118

# %%
def display_images(images, labels):
    fig, axes = plt.subplots(1, len(images), figsize=(20, 5))
    for idx, image in enumerate(images):
        axes[idx].imshow(transforms.ToPILImage()(image))
        axes[idx].set_title(labels[idx])
        axes[idx].axis('off')
    plt.show()

# %%
# Get random indices
indices = torch.randperm(len(cifar10_dataset))[:10]

# Get random images and labels
random_images = [cifar10_dataset[i][0] for i in indices]
random_labels = [cifar10_dataset.classes[cifar10_dataset[i][1]] for i in indices]  # Getting class names instead of numerical labels

# Display the images
display_images(random_images, random_labels)

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Set up data transform to convert images to tensors
transform = transforms.ToTensor()

# Load the KMNIST dataset
kmnist_dataset = datasets.KMNIST(root='./data', train=True, download=True, transform=transform)
# Out:
# ...
# 100%|██████████| 18165135/18165135 [00:16<00:00, 1122903.53it/s]
# Extracting ./data/KMNIST/raw/train-images-idx3-ubyte.gz to ./data/KMNIST/raw
#
# ...
# 100%|██████████| 29497/29497 [00:00<00:00, 181310.48it/s]
# Extracting ./data/KMNIST/raw/train-labels-idx1-ubyte.gz to ./data/KMNIST/raw
#
# ...
# 100%|██████████| 3041136/3041136 [00:03<00:00, 909097.18it/s]
# Extracting ./data/KMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/KMNIST/raw
#
# ...
# 100%|██████████| 5120/5120 [00:00<00:00, 16134362.49it/s]
# Extracting ./data/KMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/KMNIST/raw

# %%
def display_images(images, labels):
    fig, axes = plt.subplots(2, 5, figsize=(5, 5))  # 2 rows, 5 columns, 10 inches by 5 inches
    axes = axes.ravel()  # Flatten the array of axes to easily iterate through it
    for idx, image in enumerate(images):
        axes[idx].imshow(transforms.ToPILImage()(image), cmap='gray')
        axes[idx].set_title(labels[idx])
        axes[idx].axis('off')
    plt.tight_layout()  # Adjusts the spacing between subplots
    plt.show()

# Get random indices
indices = torch.randperm(len(kmnist_dataset))[:10]

# Get random images and labels
random_images = [kmnist_dataset[i][0] for i in indices]
random_labels = [str(kmnist_dataset[i][1]) for i in indices]

# Display the images
display_images(random_images, random_labels)
